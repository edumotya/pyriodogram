# %%
import ndft_features as ndft
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace( - 2*np.pi, 2*np.pi, 100)
s = np.sin(t)

# %%
plt.plot(t,s)
plt.xlabel('time [s]')
# Out:
# Text(0.5, 0, 'time [s]')

# %%
freqs, mag, phase, Pn, proba = ndft.plot(t,s,)
